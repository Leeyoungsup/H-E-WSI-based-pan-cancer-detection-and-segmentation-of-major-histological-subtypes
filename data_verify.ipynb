# %%
import os
from glob import glob
from tqdm import tqdm
import pandas as pd

# %%
df = pd.read_csv('../../data/spatialTranscriptome/meta_df.csv')
df = df[df['species'] == 'Homo sapiens'].copy()
df['organ'].value_counts(dropna=False).head(11)
# Out:
# Breast      128
# Bowel        84
# Skin         80
# Kidney       65
# Lung         64
# Heart        62
# Prostate     61
# Brain        43
# Uterus       17
# Liver        16
# Pancreas      9
# Name: organ, dtype: int64
